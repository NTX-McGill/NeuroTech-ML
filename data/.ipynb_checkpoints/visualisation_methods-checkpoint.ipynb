# %%
import display_data

# %%
display_data.get_ms('18:00:54:044443')
# Out:
# 1581289254044.4429

# %%
display_data.display_spec()
# Out:
# Notch filter removing: 57.0-63.0 Hz
# Notch filter removing: 57.0-63.0 Hz
# Notch filter removing: 57.0-63.0 Hz
# Notch filter removing: 57.0-63.0 Hz
# Notch filter removing: 57.0-63.0 Hz

# %%
eeg,timestamps,start,end,df_labels = load_dta()
