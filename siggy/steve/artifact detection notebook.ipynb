# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
from scipy import signal

# %% [markdown]
# import the signals

# %%
import os
os.listdir("../../data/")
# Out:
# ['messing_with_data_1(steve).ipynb',
#  '001_trial1_right_log_18-09-46-931825.txt',
#  '001_trial1_right_OpenBCI-RAW-2020-02-09_17-59-22.txt',
#  '.ipynb_checkpoints']

# %%
cols = ['ch1','ch2','ch7','ch8']
df1 = pd.read_csv('../../data/001_trial1_right_OpenBCI-RAW-2020-02-09_17-59-22.txt',
          sep=', ', names=cols,skiprows=6,
          usecols=[1,2,7,8],engine='python')
df1['key'] = 0
df_keystrokes = pd.read_csv('../../data/001_trial1_right_log_18-09-46-931825.txt')
# df_keystrokes.head()

# %% [markdown]
# display the figure

# %%
plt.figure(figsize=(15,10))
# plot the plot
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.plot(df1[cols[i]].values)
    
plt.show()

# %% [markdown]
# make some filters

# %%
# simple convolution, floors every good signal to 0, hopefully picks up on artifacts
def artifact_floor():
